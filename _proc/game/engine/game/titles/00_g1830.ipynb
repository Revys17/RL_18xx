# %% [raw]
# ---
# output-file: g1830.html
# title: '1830'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This class contains the title-specific configuration and metadata for 1830.

# %% [markdown]
# # Entities

# %%
#| echo: false
#| output: asis
show_doc(Entities)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/game/title/g1830.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### Entities
#
# >      Entities ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Map

# %%
#| echo: false
#| output: asis
show_doc(Map)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/game/title/g1830.py#L225){target="_blank" style="float:right; font-size:smaller"}
#
# ### Map
#
# >      Map ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Meta

# %%
#| echo: false
#| output: asis
show_doc(Meta)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/game/title/g1830.py#L430){target="_blank" style="float:right; font-size:smaller"}
#
# ### Meta
#
# >      Meta ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
meta = Meta()
meta.title()
# Out:
# 'Meta'

# %% [markdown]
# # Game

# %%
#| echo: false
#| output: asis
show_doc(Game)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/game/title/g1830.py#L458){target="_blank" style="float:right; font-size:smaller"}
#
# ### Game
#
# >      Game (names, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.
