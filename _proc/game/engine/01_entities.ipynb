# %% [raw]
# ---
# output-file: entities.html
# title: Game Entities
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# We define all required game entity types in this notebook.

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Operator

# %%
#| echo: false
#| output: asis
show_doc(Operator)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### Operator
#
# >      Operator (**kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Share Bundle

# %%
#| echo: false
#| output: asis
show_doc(ShareBundle)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L91){target="_blank" style="float:right; font-size:smaller"}
#
# ### ShareBundle
#
# >      ShareBundle (shares, percent=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Share

# %%
#| echo: false
#| output: asis
show_doc(Share)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L186){target="_blank" style="float:right; font-size:smaller"}
#
# ### Share
#
# >      Share (corporation, owner=None, president=False, percent=10, index=0,
# >             cert_size=1)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Share Pool

# %%
#| echo: false
#| output: asis
show_doc(SharePool)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L264){target="_blank" style="float:right; font-size:smaller"}
#
# ### SharePool
#
# >      SharePool (game, allow_president_sale=False,
# >                 no_rebundle_president_buy=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Depot

# %%
#| echo: false
#| output: asis
show_doc(Depot)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L675){target="_blank" style="float:right; font-size:smaller"}
#
# ### Depot
#
# >      Depot (trains, game)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Train

# %%
#| echo: false
#| output: asis
show_doc(Train)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L490){target="_blank" style="float:right; font-size:smaller"}
#
# ### Train
#
# >      Train (name:str, distance:Union[int,List[dict]], price:int, index:int=0,
# >             **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Company

# %%
#| echo: false
#| output: asis
show_doc(Company)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L983){target="_blank" style="float:right; font-size:smaller"}
#
# ### Company
#
# >      Company (sym=None, name=None, value=None, revenue=0, desc='',
# >               abilities=[], **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
args = {
    "name": "Schuylkill Valley",
    "sym": "SV",
    "value": 20,
    "revenue": 5,
    "desc": "No special abilities. Blocks G15 while owned by a player.",
    "abilities": [{"type": "blocks_hexes", "owner_type": "player", "hexes": ["G15"]}],
    "color": None,
}
SV = Company(**args)
SV, SV.sym, SV.id
# Out:
# (<Company: SV>, 'SV', 'SV')

# %% [markdown]
# ## Bank

# %%
#| echo: false
#| output: asis
show_doc(Bank)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L1072){target="_blank" style="float:right; font-size:smaller"}
#
# ### Bank
#
# >      Bank (cash, log=None, check=True)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Corporation

# %%
#| echo: false
#| output: asis
show_doc(Corporation)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L1112){target="_blank" style="float:right; font-size:smaller"}
#
# ### Corporation
#
# >      Corporation (sym=None, name=None, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
# Example usage

c = Corporation(
    {
        "float_percent": 60,
        "sym": "PRR",
        "name": "Pennsylvania Railroad",
        "logo": "18_chesapeake/PRR",
        "simple_logo": "1830/PRR.alt",
        "tokens": [0, 40, 100, 100],
        "coordinates": "H12",
        "color": "#32763f",
    }
)
c.shares_by_corporation

# %% [markdown]
# ## Loan

# %%
#| echo: false
#| output: asis
show_doc(Loan)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L1463){target="_blank" style="float:right; font-size:smaller"}
#
# ### Loan
#
# >      Loan (id, amount)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Minor

# %%
#| echo: false
#| output: asis
show_doc(Minor)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L1469){target="_blank" style="float:right; font-size:smaller"}
#
# ### Minor
#
# >      Minor (sym, name, abilities=None, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## PlayerInfo

# %%
#| echo: false
#| output: asis
show_doc(PlayerInfo)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L1538){target="_blank" style="float:right; font-size:smaller"}
#
# ### PlayerInfo
#
# >      PlayerInfo (round_name, turn, round_no, player_value)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Player

# %%
#| echo: false
#| output: asis
show_doc(Player)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/entities.py#L1552){target="_blank" style="float:right; font-size:smaller"}
#
# ### Player
#
# >      Player (id, name)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Testing

# %%
p = Player(1, "a")
p.__hash__()
