# %% [raw]
# ---
# output-file: core.html
# title: Core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This notebook contains the basic high-level types and helper methods used by other parts of the engine.

# %% [markdown]
# ## Helper Methods

# %%
#| echo: false
#| output: asis
show_doc(snake_to_pascal)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### snake_to_pascal
#
# >      snake_to_pascal (snake_str)

# %%
#| echo: false
#| output: asis
show_doc(pascal_to_snake)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### pascal_to_snake
#
# >      pascal_to_snake (pascal_str)

# %% [markdown]
# ## Errors

# %%
#| echo: false
#| output: asis
show_doc(ReusesCity)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReusesCity
#
#
#
# Unspecified run-time error.

# %%
#| echo: false
#| output: asis
show_doc(RouteTooLong)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### RouteTooLong
#
#
#
# Unspecified run-time error.

# %%
#| echo: false
#| output: asis
show_doc(RouteTooShort)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### RouteTooShort
#
#
#
# Unspecified run-time error.

# %%
#| echo: false
#| output: asis
show_doc(NoToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### NoToken
#
#
#
# Unspecified run-time error.

# %%
#| echo: false
#| output: asis
show_doc(OptionError)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### OptionError
#
#
#
# Unspecified run-time error.

# %%
#| echo: false
#| output: asis
show_doc(GameError)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### GameError
#
#
#
# Unspecified run-time error.

# %% [markdown]
# ## Logging

# %% [markdown]
# A game log that stores messages along with associated action IDs.

# %%
#| echo: false
#| output: asis
show_doc(GameLog)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### GameLog
#
# >      GameLog (game)
#
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %% [markdown]
# # Base Entities

# %% [markdown]
# ## Assignable

# %%
#| echo: false
#| output: asis
show_doc(Assignable)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L68){target="_blank" style="float:right; font-size:smaller"}
#
# ### Assignable
#
# >      Assignable ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Entity
#
# Intended to be inherited by all Game Entities.

# %%
#| echo: false
#| output: asis
show_doc(Entity)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L93){target="_blank" style="float:right; font-size:smaller"}
#
# ### Entity
#
# >      Entity ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Item

# %%
#| echo: false
#| output: asis
show_doc(Item)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L122){target="_blank" style="float:right; font-size:smaller"}
#
# ### Item
#
# >      Item (description='', cost=0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Ownable
#
# An interface inherited by all entities that can be owned. Contains an `owner` field and helper methods.

# %%
#| echo: false
#| output: asis
show_doc(Ownable)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L131){target="_blank" style="float:right; font-size:smaller"}
#
# ### Ownable
#
# >      Ownable ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Passer
#
# Contains methods around passing. Should be inherited by anything that can act in the stock round.

# %%
#| echo: false
#| output: asis
show_doc(Passer)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L178){target="_blank" style="float:right; font-size:smaller"}
#
# ### Passer
#
# >      Passer ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Share Price

# %%
#| echo: false
#| output: asis
show_doc(SharePrice)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L200){target="_blank" style="float:right; font-size:smaller"}
#
# ### SharePrice
#
# >      SharePrice (code, row, column, unlimited_types=None,
# >                  multiple_buy_types=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Shareholder

# %%
#| echo: false
#| output: asis
show_doc(ShareHolder)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L308){target="_blank" style="float:right; font-size:smaller"}
#
# ### ShareHolder
#
# >      ShareHolder ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Spender

# %%
#| echo: false
#| output: asis
show_doc(Spender)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L360){target="_blank" style="float:right; font-size:smaller"}
#
# ### Spender
#
# >      Spender ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Stock Movement

# %%
#| echo: false
#| output: asis
show_doc(ZigZagMovement)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L465){target="_blank" style="float:right; font-size:smaller"}
#
# ### ZigZagMovement
#
# >      ZigZagMovement (market, ledge_movement)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(OneDimensionalMovement)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L445){target="_blank" style="float:right; font-size:smaller"}
#
# ### OneDimensionalMovement
#
# >      OneDimensionalMovement (market)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(TwoDimensionalMovement)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L417){target="_blank" style="float:right; font-size:smaller"}
#
# ### TwoDimensionalMovement
#
# >      TwoDimensionalMovement (market)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(BaseMovement)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L392){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseMovement
#
# >      BaseMovement (market)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Stock Market

# %%
#| echo: false
#| output: asis
show_doc(StockMarket)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L501){target="_blank" style="float:right; font-size:smaller"}
#
# ### StockMarket
#
# >      StockMarket (market, unlimited_types, multiple_buy_types=None,
# >                   zigzag=None, ledge_movement=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Game Flow

# %% [markdown]
# ## Phase

# %%
#| echo: false
#| output: asis
show_doc(Phase)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/core.py#L643){target="_blank" style="float:right; font-size:smaller"}
#
# ### Phase
#
# >      Phase (phases, game)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Testing

# %%
class TestTiles:
    TEST_TILES_HUMAN_READABLE = [
        {"tile": "45"},
        {"tile": "H11", "title": "1822PNW"},
        {"tile": "O8", "title": "1822PNW"},
        {"tile": "I12", "title": "1822PNW"},
        # open: https://github.com/tobymao/18xx/issues/5981
        {"tile": "H22", "title": "1828.Games"},
        # open: https://github.com/tobymao/18xx/issues/8178
        {"tile": "H18", "title": "1830", "fixture": "26855", "action": 385},
        {"tile": "C15", "title": "1846"},
        # open: https://github.com/tobymao/18xx/issues/5167
        {"tile": "N11", "title": "1856", "fixture": "hotseat005", "action": 113},
        {"tile": "L0", "title": "1868 Wyoming"},
        {"tile": "WRC", "title": "1868 Wyoming"},
        {"tile": "F12", "title": "1868 Wyoming", "fixture": "1868WY_5", "action": 835},
        {"tile": "L0", "title": "1868 Wyoming", "fixture": "1868WY_5", "action": 835},
        {"tile": "J12", "title": "1868 Wyoming", "fixture": "1868WY_5", "action": 835},
        {"tile": "J12", "title": "1868 Wyoming", "fixture": "1868WY_5"},
        # open: https://github.com/tobymao/18xx/issues/4992
        {"tile": "I11", "title": "1882", "fixture": "5236", "action": 303},
        # open: https://github.com/tobymao/18xx/issues/6604
        {"tile": "L41", "title": "1888"},
        # open: https://github.com/tobymao/18xx/issues/5153
        {"tile": "IR7", "title": "18Ireland"},
        {"tile": "IR8", "title": "18Ireland"},
        # open: https://github.com/tobymao/18xx/issues/5673
        {"tile": "D19", "title": "18Mag", "fixture": "hs_tfagolvf_76622"},
        {"tile": "I14", "title": "18Mag", "fixture": "hs_tfagolvf_76622"},
        # open: https://github.com/tobymao/18xx/issues/7765
        {"tile": "470", "title": "18MEX"},
        {"tile": "475", "title": "18MEX"},
        {"tile": "479P", "title": "18MEX"},
        {"tile": "485P", "title": "18MEX"},
        {"tile": "486P", "title": "18MEX"},
    ]

    TEST_TILES = {}
    for opts in TEST_TILES_HUMAN_READABLE:
        tile = opts["tile"]
        title = opts.get("title", "DefaultTitle")
        fixture = opts.get("fixture", "DefaultFixture")
        action = opts.get("action", "DefaultAction")

        if title not in TEST_TILES:
            TEST_TILES[title] = {}

        if fixture not in TEST_TILES[title]:
            TEST_TILES[title][fixture] = {}

        if action not in TEST_TILES[title][fixture]:
            TEST_TILES[title][fixture][action] = []

        TEST_TILES[title][fixture][action].append([tile, opts])

# %%
TestTiles.TEST_TILES
# Out:
# {'DefaultTitle': {'DefaultFixture': {'DefaultAction': [['45',
#      {'tile': '45'}]]}},
#  '1822PNW': {'DefaultFixture': {'DefaultAction': [['H11',
#      {'tile': 'H11', 'title': '1822PNW'}],
#     ['O8', {'tile': 'O8', 'title': '1822PNW'}],
#     ['I12', {'tile': 'I12', 'title': '1822PNW'}]]}},
#  '1828.Games': {'DefaultFixture': {'DefaultAction': [['H22',
#      {'tile': 'H22', 'title': '1828.Games'}]]}},
#  '1830': {'26855': {385: [['H18',
#      {'tile': 'H18', 'title': '1830', 'fixture': '26855', 'action': 385}]]}},
#  '1846': {'DefaultFixture': {'DefaultAction': [['C15',
#      {'tile': 'C15', 'title': '1846'}]]}},
#  '1856': {'hotseat005': {113: [['N11',
#      {'tile': 'N11',
#       'title': '1856',
#       'fixture': 'hotseat005',
#       'action': 113}]]}},
#  '1868 Wyoming': {'DefaultFixture': {'DefaultAction': [['L0',
#      {'tile': 'L0', 'title': '1868 Wyoming'}],
#     ['WRC', {'tile': 'WRC', 'title': '1868 Wyoming'}]]},
#   '1868WY_5': {835: [['F12',
#      {'tile': 'F12',
#       'title': '1868 Wyoming',
#       'fixture': '1868WY_5',
#       'action': 835}],
#     ['L0',
#      {'tile': 'L0',
#       'title': '1868 Wyoming',
#       'fixture': '1868WY_5',
#       'action': 835}],
#     ['J12',
#      {'tile': 'J12',
#       'title': '1868 Wyoming',
#       'fixture': '1868WY_5',
#       'action': 835}]],
#    'DefaultAction': [['J12',
#      {'tile': 'J12', 'title': '1868 Wyoming', 'fixture': '1868WY_5'}]]}},
#  '1882': {'5236': {303: [['I11',
#      {'tile': 'I11', 'title': '1882', 'fixture': '5236', 'action': 303}]]}},
#  '1888': {'DefaultFixture': {'DefaultAction': [['L41',
#      {'tile': 'L41', 'title': '1888'}]]}},
#  '18Ireland': {'DefaultFixture': {'DefaultAction': [['IR7',
#      {'tile': 'IR7', 'title': '18Ireland'}],
#     ['IR8', {'tile': 'IR8', 'title': '18Ireland'}]]}},
#  '18Mag': {'hs_tfagolvf_76622': {'DefaultAction': [['D19',
#      {'tile': 'D19', 'title': '18Mag', 'fixture': 'hs_tfagolvf_76622'}],
#     ['I14',
#      {'tile': 'I14', 'title': '18Mag', 'fixture': 'hs_tfagolvf_76622'}]]}},
#  '18MEX': {'DefaultFixture': {'DefaultAction': [['470',
#      {'tile': '470', 'title': '18MEX'}],
#     ['475', {'tile': '475', 'title': '18MEX'}],
#     ['479P', {'tile': '479P', 'title': '18MEX'}],
#     ['485P', {'tile': '485P', 'title': '18MEX'}],
#     ['486P', {'tile': '486P', 'title': '18MEX'}]]}}}

# %% [markdown]
# # Publisher Info

# %%
PUBLISHER_INFO
# Out:
# {'all_aboard_games': {'name': 'All-Aboard Games',
#   'url': 'https://all-aboardgames.com/'},
#  'deep_thought_games': {'name': 'Deep Thought Games',
#   'url': 'https://boardgamegeek.com/boardgamepublisher/4192/deep-thought-games-llc',
#   'hidden': True},
#  'gmt_games': {'name': 'GMT Games', 'url': 'https://www.gmtgames.com/'},
#  'golden_spike': {'name': 'Golden Spike Games',
#   'url': 'https://goldenspikegames.com/'},
#  'grand_trunk_games': {'name': 'Grand Trunk Games',
#   'url': 'https://www.grandtrunkgames.com/'},
#  'lonny_games': {'name': 'Lonny Games', 'url': 'https://www.lonnygames.com/'},
#  'lookout': {'name': 'Lookout Games',
#   'url': 'https://lookout-spiele.de/',
#   'hidden': True},
#  'loserdogs': {'name': 'Loserdogs',
#   'url': 'http://tanisan.com/ld/',
#   'hidden': True},
#  'marflow_games': {'name': 'Marflow Games',
#   'url': 'https://18xx-marflow-games.de/'},
#  'mayfair': {'name': 'Mayfair Games',
#   'url': 'https://boardgamegeek.com/boardgamepublisher/10/mayfair-games',
#   'hidden': True},
#  'mercury': {'name': 'Mercury Games',
#   'url': 'https://www.mercurygames.com/',
#   'hidden': True},
#  'oo_games': {'name': 'Double-O Games',
#   'url': 'http://ohley.de/english/',
#   'hidden': True},
#  'seahorse': {'name': 'Seahorse Laser & Design',
#   'url': 'https://www.etsy.com/shop/SeahorseLaserDesign?section_id=24360565',
#   'hidden': True},
#  'self_published': {'name': 'Self-published',
#   'url': 'https://18xx.games',
#   'hidden': True},
#  'traxx': {'name': 'TraXX', 'url': 'https://traxx-denver.com/games/'},
#  'zman_games': {'name': 'Z-MAN Games',
#   'url': 'https://zmangames.com/',
#   'hidden': True}}
