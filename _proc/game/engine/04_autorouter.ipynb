# %% [raw]
# ---
# output-file: autorouter.html
# title: Auto Router
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(AutoRouter)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/autorouter.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### AutoRouter
#
# >      AutoRouter (game, flash=None, debug=False, verbose=False)
#
# Initialize self.  See help(type(self)) for accurate signature.
