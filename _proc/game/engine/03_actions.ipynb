# %% [raw]
# ---
# output-file: actions.html
# title: Actions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # Base Action Class

# %%
#| echo: false
#| output: asis
show_doc(BaseAction)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseAction
#
# >      BaseAction (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Action Implementations

# %% [markdown]
# ## Acquire Company

# %%
#| echo: false
#| output: asis
show_doc(AcquireCompany)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1228){target="_blank" style="float:right; font-size:smaller"}
#
# ### AcquireCompany
#
# >      AcquireCompany (entity, company)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Assign

# %%
#| echo: false
#| output: asis
show_doc(Assign)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1275){target="_blank" style="float:right; font-size:smaller"}
#
# ### Assign
#
# >      Assign (entity, target)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Bankrupt

# %%
#| echo: false
#| output: asis
show_doc(Bankrupt)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1395){target="_blank" style="float:right; font-size:smaller"}
#
# ### Bankrupt
#
# >      Bankrupt (entity, option=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Bid

# %%
#| echo: false
#| output: asis
show_doc(Bid)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L176){target="_blank" style="float:right; font-size:smaller"}
#
# ### Bid
#
# >      Bid (entity, price, company=None, corporation=None, minor=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Blind Bid

# %%
#| echo: false
#| output: asis
show_doc(BlindBid)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L212){target="_blank" style="float:right; font-size:smaller"}
#
# ### BlindBid
#
# >      BlindBid (entity, bids=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Borrow Train

# %%
#| echo: false
#| output: asis
show_doc(BorrowTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L227){target="_blank" style="float:right; font-size:smaller"}
#
# ### BorrowTrain
#
# >      BorrowTrain (entity, train)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Buy Company

# %%
#| echo: false
#| output: asis
show_doc(BuyCompany)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1452){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyCompany
#
# >      BuyCompany (entity, company, price)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Buy Corporation

# %%
#| echo: false
#| output: asis
show_doc(BuyCorporation)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L259){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyCorporation
#
# >      BuyCorporation (entity, price, corporation=None, minor=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Buy Power

# %%
#| echo: false
#| output: asis
show_doc(BuyPower)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L282){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyPower
#
# >      BuyPower (entity, power)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Buy Shares

# %%
#| echo: false
#| output: asis
show_doc(BuyShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L295){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyShares
#
# >      BuyShares (entity, shares, share_price=None, percent=None, swap=None,
# >                 purchase_for=None, borrow_from=None, total_price=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Sell Shares

# %%
#| echo: false
#| output: asis
show_doc(SellShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L354){target="_blank" style="float:right; font-size:smaller"}
#
# ### SellShares
#
# >      SellShares (entity, shares, share_price=None, percent=None, swap=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Buy Token

# %%
#| echo: false
#| output: asis
show_doc(BuyToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L387){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyToken
#
# >      BuyToken (entity, city, slot, price)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Buy Train

# %%
#| echo: false
#| output: asis
show_doc(BuyTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L774){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyTrain
#
# >      BuyTrain (entity, train, price, variant=None, exchange=None, shell=None,
# >                slots=None, extra_due=None, warranties=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Choose

# %%
#| echo: false
#| output: asis
show_doc(Choose)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L472){target="_blank" style="float:right; font-size:smaller"}
#
# ### Choose
#
# >      Choose (entity, choice)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Choose Ability

# %%
#| echo: false
#| output: asis
show_doc(ChooseAbility)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L487){target="_blank" style="float:right; font-size:smaller"}
#
# ### ChooseAbility
#
# >      ChooseAbility (entity, choice)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Claim Hex Token

# %%
#| echo: false
#| output: asis
show_doc(ClaimHexToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L491){target="_blank" style="float:right; font-size:smaller"}
#
# ### ClaimHexToken
#
# >      ClaimHexToken (entity, hex, token_type=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Combined Trains

# %%
#| echo: false
#| output: asis
show_doc(CombinedTrains)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L511){target="_blank" style="float:right; font-size:smaller"}
#
# ### CombinedTrains
#
# >      CombinedTrains (entity, base, additional_train, additional_train_variant)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Convert

# %%
#| echo: false
#| output: asis
show_doc(Convert)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L534){target="_blank" style="float:right; font-size:smaller"}
#
# ### Convert
#
# >      Convert (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Corporate Buy Shares

# %%
#| echo: false
#| output: asis
show_doc(CorporateBuyShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2672){target="_blank" style="float:right; font-size:smaller"}
#
# ### CorporateBuyShares
#
# >      CorporateBuyShares (entity, shares, share_price=None, percent=None,
# >                          swap=None, purchase_for=None, borrow_from=None,
# >                          total_price=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Corporate Sell Shares

# %%
#| echo: false
#| output: asis
show_doc(CorporateSellShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2790){target="_blank" style="float:right; font-size:smaller"}
#
# ### CorporateSellShares
#
# >      CorporateSellShares (entity, shares, share_price=None, percent=None,
# >                           swap=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Credit Mobilier

# %%
#| echo: false
#| output: asis
show_doc(CreditMobilier)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L546){target="_blank" style="float:right; font-size:smaller"}
#
# ### CreditMobilier
#
# >      CreditMobilier (entity, hex, amount)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Destination Connection

# %%
#| echo: false
#| output: asis
show_doc(DestinationConnection)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L560){target="_blank" style="float:right; font-size:smaller"}
#
# ### DestinationConnection
#
# >      DestinationConnection (entity, corporations=None, minors=None,
# >                             hexes=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Discard Train

# %%
#| echo: false
#| output: asis
show_doc(DiscardTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2861){target="_blank" style="float:right; font-size:smaller"}
#
# ### DiscardTrain
#
# >      DiscardTrain (entity, train)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Dividend

# %%
#| echo: false
#| output: asis
show_doc(Dividend)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2891){target="_blank" style="float:right; font-size:smaller"}
#
# ### Dividend
#
# >      Dividend (entity, kind, amount=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Double Head Trains

# %%
#| echo: false
#| output: asis
show_doc(DoubleHeadTrains)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L627){target="_blank" style="float:right; font-size:smaller"}
#
# ### DoubleHeadTrains
#
# >      DoubleHeadTrains (entity, trains)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## End Game

# %%
#| echo: false
#| output: asis
show_doc(EndGame)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3107){target="_blank" style="float:right; font-size:smaller"}
#
# ### EndGame
#
# >      EndGame (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Failed Merge

# %%
#| echo: false
#| output: asis
show_doc(FailedMerge)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L649){target="_blank" style="float:right; font-size:smaller"}
#
# ### FailedMerge
#
# >      FailedMerge (entity, corporations)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Hex Token

# %%
#| echo: false
#| output: asis
show_doc(HexToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L668){target="_blank" style="float:right; font-size:smaller"}
#
# ### HexToken
#
# >      HexToken (entity, hex, cost=None, token_type=None, token=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Lay Tile

# %%
#| echo: false
#| output: asis
show_doc(LayTile)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L691){target="_blank" style="float:right; font-size:smaller"}
#
# ### LayTile
#
# >      LayTile (entity, tile, hex, rotation, combo_entities=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Message

# %%
#| echo: false
#| output: asis
show_doc(Message)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3317){target="_blank" style="float:right; font-size:smaller"}
#
# ### Message
#
# >      Message (entity, message)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Log

# %%
#| echo: false
#| output: asis
show_doc(Log)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L744){target="_blank" style="float:right; font-size:smaller"}
#
# ### Log
#
# >      Log (entity, message)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Manual Close Company

# %%
#| echo: false
#| output: asis
show_doc(ManualCloseCompany)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L748){target="_blank" style="float:right; font-size:smaller"}
#
# ### ManualCloseCompany
#
# >      ManualCloseCompany (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Merge

# %%
#| echo: false
#| output: asis
show_doc(Merge)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L752){target="_blank" style="float:right; font-size:smaller"}
#
# ### Merge
#
# >      Merge (entity, corporation=None, minor=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Move Bid

# %%
#| echo: false
#| output: asis
show_doc(MoveBid)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L772){target="_blank" style="float:right; font-size:smaller"}
#
# ### MoveBid
#
# >      MoveBid (entity, price, from_company, from_price, company=None,
# >               corporation=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Offer

# %%
#| echo: false
#| output: asis
show_doc(Offer)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L803){target="_blank" style="float:right; font-size:smaller"}
#
# ### Offer
#
# >      Offer (entity, corporation=None, company=None, price=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Par

# %%
#| echo: false
#| output: asis
show_doc(Par)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L826){target="_blank" style="float:right; font-size:smaller"}
#
# ### Par
#
# >      Par (entity, corporation, share_price, slot=None, purchase_for=None,
# >           borrow_from=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Pass

# %%
#| echo: false
#| output: asis
show_doc(Pass)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L936){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pass
#
# >      Pass (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Pay off Debt

# %%
#| echo: false
#| output: asis
show_doc(PayoffDebt)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L908){target="_blank" style="float:right; font-size:smaller"}
#
# ### PayoffDebt
#
# >      PayoffDebt (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Take Loan

# %%
#| echo: false
#| output: asis
show_doc(TakeLoan)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L887){target="_blank" style="float:right; font-size:smaller"}
#
# ### TakeLoan
#
# >      TakeLoan (entity, loan)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Pay off Loan

# %%
#| echo: false
#| output: asis
show_doc(PayoffDebt)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L908){target="_blank" style="float:right; font-size:smaller"}
#
# ### PayoffDebt
#
# >      PayoffDebt (entity, loan)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Pay off Player Debt

# %%
#| echo: false
#| output: asis
show_doc(PayoffPlayerDebt)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L912){target="_blank" style="float:right; font-size:smaller"}
#
# ### PayoffPlayerDebt
#
# >      PayoffPlayerDebt (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Place Token

# %%
#| echo: false
#| output: asis
show_doc(PlaceToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L916){target="_blank" style="float:right; font-size:smaller"}
#
# ### PlaceToken
#
# >      PlaceToken (entity, city, slot, cost=None, tokener=None, token_type=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Enable

# %%
#| echo: false
#| output: asis
show_doc(ProgramEnable)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L950){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramEnable
#
# >      ProgramEnable (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Disable

# %%
#| echo: false
#| output: asis
show_doc(ProgramDisable)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L955){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramDisable
#
# >      ProgramDisable (entity, reason, original_type=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Auction Bid

# %%
#| echo: false
#| output: asis
show_doc(ProgramAuctionBid)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L975){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramAuctionBid
#
# >      ProgramAuctionBid (entity, bid_target, maximum_bid, buy_price,
# >                         enable_maximum_bid=False, enable_buy_price=False,
# >                         auto_pass_after=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Buy Shares

# %%
#| echo: false
#| output: asis
show_doc(ProgramBuyShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1035){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramBuyShares
#
# >      ProgramBuyShares (entity, corporation, until_condition,
# >                        from_market=False, auto_pass_after=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Close Pass

# %%
#| echo: false
#| output: asis
show_doc(ProgramClosePass)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1082){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramClosePass
#
# >      ProgramClosePass (entity, unconditional=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Harzbahn Draft Pass

# %%
#| echo: false
#| output: asis
show_doc(ProgramHarzbahnDraftPass)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1106){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramHarzbahnDraftPass
#
# >      ProgramHarzbahnDraftPass (entity, until_premium, unconditional)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Independent Mines

# %%
#| echo: false
#| output: asis
show_doc(ProgramIndependentMines)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1136){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramIndependentMines
#
# >      ProgramIndependentMines (entity, skip_track, skip_buy, skip_close,
# >                               indefinite)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Merger Pass

# %%
#| echo: false
#| output: asis
show_doc(ProgramMergerPass)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1178){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramMergerPass
#
# >      ProgramMergerPass (entity, corporations_by_round, options)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Program Share Pass

# %%
#| echo: false
#| output: asis
show_doc(ProgramSharePass)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1223){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgramSharePass
#
# >      ProgramSharePass (entity, unconditional=False, indefinite=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Purchase Train

# %%
#| echo: false
#| output: asis
show_doc(PurchaseTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1251){target="_blank" style="float:right; font-size:smaller"}
#
# ### PurchaseTrain
#
# >      PurchaseTrain (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Reassign Trains

# %%
#| echo: false
#| output: asis
show_doc(ReassignTrains)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1255){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReassignTrains
#
# >      ReassignTrains (entity, assignments=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Redo

# %%
#| echo: false
#| output: asis
show_doc(Redo)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1287){target="_blank" style="float:right; font-size:smaller"}
#
# ### Redo
#
# >      Redo (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Remove Hex Token

# %%
#| echo: false
#| output: asis
show_doc(RemoveHexToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1292){target="_blank" style="float:right; font-size:smaller"}
#
# ### RemoveHexToken
#
# >      RemoveHexToken (entity, hex)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Remove Token

# %%
#| echo: false
#| output: asis
show_doc(RemoveToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1309){target="_blank" style="float:right; font-size:smaller"}
#
# ### RemoveToken
#
# >      RemoveToken (entity, city, slot)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Respond

# %%
#| echo: false
#| output: asis
show_doc(Respond)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1329){target="_blank" style="float:right; font-size:smaller"}
#
# ### Respond
#
# >      Respond (entity, corporation, company, accept)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Run Routes

# %%
#| echo: false
#| output: asis
show_doc(RunRoutes)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1352){target="_blank" style="float:right; font-size:smaller"}
#
# ### RunRoutes
#
# >      RunRoutes (entity, routes, extra_revenue=0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Scrap Train

# %%
#| echo: false
#| output: asis
show_doc(ScrapTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1412){target="_blank" style="float:right; font-size:smaller"}
#
# ### ScrapTrain
#
# >      ScrapTrain (entity, train)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Sell Company

# %%
#| echo: false
#| output: asis
show_doc(SellCompany)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1429){target="_blank" style="float:right; font-size:smaller"}
#
# ### SellCompany
#
# >      SellCompany (entity, company, price)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Short

# %%
#| echo: false
#| output: asis
show_doc(Short)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1449){target="_blank" style="float:right; font-size:smaller"}
#
# ### Short
#
# >      Short (entity, corporation)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Special Buy

# %%
#| echo: false
#| output: asis
show_doc(SpecialBuy)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4215){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpecialBuy
#
# >      SpecialBuy (entity, item)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Split

# %%
#| echo: false
#| output: asis
show_doc(Split)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1484){target="_blank" style="float:right; font-size:smaller"}
#
# ### Split
#
# >      Split (entity, corporation)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Swap Train

# %%
#| echo: false
#| output: asis
show_doc(SwapTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1501){target="_blank" style="float:right; font-size:smaller"}
#
# ### SwapTrain
#
# >      SwapTrain (entity, train)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Switch Trains

# %%
#| echo: false
#| output: asis
show_doc(SwitchTrains)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1518){target="_blank" style="float:right; font-size:smaller"}
#
# ### SwitchTrains
#
# >      SwitchTrains (entity, slots=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Undo

# %%
#| echo: false
#| output: asis
show_doc(Undo)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1537){target="_blank" style="float:right; font-size:smaller"}
#
# ### Undo
#
# >      Undo (entity, action_id=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Use Graph

# %%
#| echo: false
#| output: asis
show_doc(UseGraph)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1554){target="_blank" style="float:right; font-size:smaller"}
#
# ### UseGraph
#
# >      UseGraph (entity, graph_id)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## View Merge Options

# %%
#| echo: false
#| output: asis
show_doc(ViewMergeOptions)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1571){target="_blank" style="float:right; font-size:smaller"}
#
# ### ViewMergeOptions
#
# >      ViewMergeOptions (entity)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Operating Info

# %%
#| echo: false
#| output: asis
show_doc(OperatingInfo)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/actions.py#L1575){target="_blank" style="float:right; font-size:smaller"}
#
# ### OperatingInfo
#
# >      OperatingInfo (runs, dividend, revenue, laid_hexes, dividend_kind=None)
#
# Initialize self.  See help(type(self)) for accurate signature.
