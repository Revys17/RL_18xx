# %% [raw]
# ---
# output-file: round.html
# title: Rounds and Steps
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Imports

# %% [markdown]
# # Steps

# %% [markdown]
# ## BaseStep

# %%
#| echo: false
#| output: asis
show_doc(BaseStep)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L61){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseStep
#
# >      BaseStep (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Step classes

# %% [markdown]
# ### Auctioner

# %%
#| echo: false
#| output: asis
show_doc(Auctioner)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L170){target="_blank" style="float:right; font-size:smaller"}
#
# ### Auctioner
#
# >      Auctioner ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Programmer

# %%
#| echo: false
#| output: asis
show_doc(Programmer)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L320){target="_blank" style="float:right; font-size:smaller"}
#
# ### Programmer
#
# >      Programmer ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Share Buying

# %%
#| echo: false
#| output: asis
show_doc(ShareBuying)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L351){target="_blank" style="float:right; font-size:smaller"}
#
# ### ShareBuying
#
# >      ShareBuying ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Emergency Money

# %%
#| echo: false
#| output: asis
show_doc(EmergencyMoney)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L426){target="_blank" style="float:right; font-size:smaller"}
#
# ### EmergencyMoney
#
# >      EmergencyMoney ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Train

# %%
#| echo: false
#| output: asis
show_doc(Train)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L490){target="_blank" style="float:right; font-size:smaller"}
#
# ### Train
#
# >      Train (game)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Buy Train

# %%
#| echo: false
#| output: asis
show_doc(BuyTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L774){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyTrain
#
# >      BuyTrain (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Passable Auction

# %%
#| echo: false
#| output: asis
show_doc(PassableAuction)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L848){target="_blank" style="float:right; font-size:smaller"}
#
# ### PassableAuction
#
# >      PassableAuction ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Tokener

# %%
#| echo: false
#| output: asis
show_doc(Tokener)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L953){target="_blank" style="float:right; font-size:smaller"}
#
# ### Tokener
#
# >      Tokener ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Token Merger

# %%
#| echo: false
#| output: asis
show_doc(TokenMerger)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1159){target="_blank" style="float:right; font-size:smaller"}
#
# ### TokenMerger
#
# >      TokenMerger ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Acquire Company

# %%
#| echo: false
#| output: asis
show_doc(AcquireCompany)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1228){target="_blank" style="float:right; font-size:smaller"}
#
# ### AcquireCompany
#
# >      AcquireCompany (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Assign

# %%
#| echo: false
#| output: asis
show_doc(Assign)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1275){target="_blank" style="float:right; font-size:smaller"}
#
# ### Assign
#
# >      Assign (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Automatic Loan

# %%
#| echo: false
#| output: asis
show_doc(AutomaticLoan)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1383){target="_blank" style="float:right; font-size:smaller"}
#
# ### AutomaticLoan
#
# >      AutomaticLoan ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Bankrupt

# %%
#| echo: false
#| output: asis
show_doc(Bankrupt)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1395){target="_blank" style="float:right; font-size:smaller"}
#
# ### Bankrupt
#
# >      Bankrupt (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Buy Company

# %%
#| echo: false
#| output: asis
show_doc(BuyCompany)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1452){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuyCompany
#
# >      BuyCompany (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Buy/Sell/Par Shares

# %%
#| echo: false
#| output: asis
show_doc(BuySellParShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L1578){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuySellParShares
#
# >      BuySellParShares (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Buy/Sell/Par Shares Companies

# %%
#| echo: false
#| output: asis
show_doc(BuySellParSharesCompanies)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2166){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuySellParSharesCompanies
#
# >      BuySellParSharesCompanies (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Buy/Sell/Par Shares via Bid

# %%
#| echo: false
#| output: asis
show_doc(BuySellParSharesViaBid)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2344){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuySellParSharesViaBid
#
# >      BuySellParSharesViaBid (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Buy Single Train of Type

# %%
#| echo: false
#| output: asis
show_doc(BuySingleTrainOfType)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2440){target="_blank" style="float:right; font-size:smaller"}
#
# ### BuySingleTrainOfType
#
# >      BuySingleTrainOfType (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Company Pending Par

# %%
#| echo: false
#| output: asis
show_doc(CompanyPendingPar)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2469){target="_blank" style="float:right; font-size:smaller"}
#
# ### CompanyPendingPar
#
# >      CompanyPendingPar (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Concession Auction

# %%
#| echo: false
#| output: asis
show_doc(ConcessionAuction)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2517){target="_blank" style="float:right; font-size:smaller"}
#
# ### ConcessionAuction
#
# >      ConcessionAuction (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Corporate Buy Shares

# %%
#| echo: false
#| output: asis
show_doc(CorporateBuyShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2672){target="_blank" style="float:right; font-size:smaller"}
#
# ### CorporateBuyShares
#
# >      CorporateBuyShares (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Corporate Sell Shares

# %%
#| echo: false
#| output: asis
show_doc(CorporateSellShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2790){target="_blank" style="float:right; font-size:smaller"}
#
# ### CorporateSellShares
#
# >      CorporateSellShares (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Discard Train

# %%
#| echo: false
#| output: asis
show_doc(DiscardTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2861){target="_blank" style="float:right; font-size:smaller"}
#
# ### DiscardTrain
#
# >      DiscardTrain (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Dividend

# %%
#| echo: false
#| output: asis
show_doc(Dividend)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L2891){target="_blank" style="float:right; font-size:smaller"}
#
# ### Dividend
#
# >      Dividend (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### End Game

# %%
#| echo: false
#| output: asis
show_doc(EndGame)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3107){target="_blank" style="float:right; font-size:smaller"}
#
# ### EndGame
#
# >      EndGame (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Exchange

# %%
#| echo: false
#| output: asis
show_doc(Exchange)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3125){target="_blank" style="float:right; font-size:smaller"}
#
# ### Exchange
#
# >      Exchange (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Half Pay

# %%
#| echo: false
#| output: asis
show_doc(HalfPay)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3193){target="_blank" style="float:right; font-size:smaller"}
#
# ### HalfPay
#
# >      HalfPay ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Home Token

# %%
#| echo: false
#| output: asis
show_doc(HomeToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3205){target="_blank" style="float:right; font-size:smaller"}
#
# ### HomeToken
#
# >      HomeToken (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Issue Shares

# %%
#| echo: false
#| output: asis
show_doc(IssueShares)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3280){target="_blank" style="float:right; font-size:smaller"}
#
# ### IssueShares
#
# >      IssueShares (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Message

# %%
#| echo: false
#| output: asis
show_doc(Message)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3317){target="_blank" style="float:right; font-size:smaller"}
#
# ### Message
#
# >      Message (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Minor Half Pay

# %%
#| echo: false
#| output: asis
show_doc(MinorHalfPay)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3345){target="_blank" style="float:right; font-size:smaller"}
#
# ### MinorHalfPay
#
# >      MinorHalfPay ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Minor Withold

# %%
#| echo: false
#| output: asis
show_doc(MinorWithhold)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3384){target="_blank" style="float:right; font-size:smaller"}
#
# ### MinorWithhold
#
# >      MinorWithhold ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Program

# %%
#| echo: false
#| output: asis
show_doc(Program)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3398){target="_blank" style="float:right; font-size:smaller"}
#
# ### Program
#
# >      Program (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Programmer Auction Bid

# %%
#| echo: false
#| output: asis
show_doc(ProgrammerAuctionBid)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3478){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgrammerAuctionBid
#
# >      ProgrammerAuctionBid ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Programmer Merger Pass

# %%
#| echo: false
#| output: asis
show_doc(ProgrammerMergerPass)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3576){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgrammerMergerPass
#
# >      ProgrammerMergerPass ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Reduce Tokens

# %%
#| echo: false
#| output: asis
show_doc(ReduceTokens)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3608){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReduceTokens
#
# >      ReduceTokens (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Return Token

# %%
#| echo: false
#| output: asis
show_doc(ReturnToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3685){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReturnToken
#
# >      ReturnToken (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Route

# %%
#| echo: false
#| output: asis
show_doc(Route)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3784){target="_blank" style="float:right; font-size:smaller"}
#
# ### Route
#
# >      Route (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Selection Auction

# %%
#| echo: false
#| output: asis
show_doc(SelectionAuction)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3859){target="_blank" style="float:right; font-size:smaller"}
#
# ### SelectionAuction
#
# >      SelectionAuction (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Simple Draft

# %%
#| echo: false
#| output: asis
show_doc(SimpleDraft)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4027){target="_blank" style="float:right; font-size:smaller"}
#
# ### SimpleDraft
#
# >      SimpleDraft (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Single Depot Train Buy

# %%
#| echo: false
#| output: asis
show_doc(SingleDepotTrainBuy)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4110){target="_blank" style="float:right; font-size:smaller"}
#
# ### SingleDepotTrainBuy
#
# >      SingleDepotTrainBuy (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Special Buy Train

# %%
#| echo: false
#| output: asis
show_doc(SpecialBuyTrain)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4145){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpecialBuyTrain
#
# >      SpecialBuyTrain (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Special Buy

# %%
#| echo: false
#| output: asis
show_doc(SpecialBuy)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4215){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpecialBuy
#
# >      SpecialBuy (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Special Choose

# %%
#| echo: false
#| output: asis
show_doc(SpecialChoose)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4259){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpecialChoose
#
# >      SpecialChoose (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Special Token

# %%
#| echo: false
#| output: asis
show_doc(SpecialToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4293){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpecialToken
#
# >      SpecialToken (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Tracker

# %%
#| echo: false
#| output: asis
show_doc(Tracker)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L4432){target="_blank" style="float:right; font-size:smaller"}
#
# ### Tracker
#
# >      Tracker ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Special Track

# %%
#| echo: false
#| output: asis
show_doc(SpecialTrack)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5033){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpecialTrack
#
# >      SpecialTrack (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Token

# %%
#| echo: false
#| output: asis
show_doc(Token)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5270){target="_blank" style="float:right; font-size:smaller"}
#
# ### Token
#
# >      Token (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Track

# %%
#| echo: false
#| output: asis
show_doc(Track)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5306){target="_blank" style="float:right; font-size:smaller"}
#
# ### Track
#
# >      Track (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Track and Token

# %%
#| echo: false
#| output: asis
show_doc(TrackAndToken)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5358){target="_blank" style="float:right; font-size:smaller"}
#
# ### TrackAndToken
#
# >      TrackAndToken (game, round, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Track Lay When Company Sold

# %%
#| echo: false
#| output: asis
show_doc(TrackLayWhenCompanySold)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5438){target="_blank" style="float:right; font-size:smaller"}
#
# ### TrackLayWhenCompanySold
#
# >      TrackLayWhenCompanySold ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Waterfall Auction

# %%
#| echo: false
#| output: asis
show_doc(WaterfallAuction)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5501){target="_blank" style="float:right; font-size:smaller"}
#
# ### WaterfallAuction
#
# >      WaterfallAuction (game, round, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Rounds

# %% [markdown]
# ### Base Class

# %%
#| echo: false
#| output: asis
show_doc(BaseRound)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5707){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseRound
#
# >      BaseRound (game, steps, round_num=1, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Auction

# %%
#| echo: false
#| output: asis
show_doc(Auction)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5936){target="_blank" style="float:right; font-size:smaller"}
#
# ### Auction
#
# >      Auction (game, steps, round_num=1, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ###  Choices

# %%
#| echo: false
#| output: asis
show_doc(Choices)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5952){target="_blank" style="float:right; font-size:smaller"}
#
# ### Choices
#
# >      Choices (game, steps, round_num=1, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Draft

# %%
#| echo: false
#| output: asis
show_doc(Draft)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5964){target="_blank" style="float:right; font-size:smaller"}
#
# ### Draft
#
# >      Draft (game, steps, reverse_order=False, snake_order=False,
# >             rotating_order=False, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Merger

# %%
#| echo: false
#| output: asis
show_doc(Merger)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L6013){target="_blank" style="float:right; font-size:smaller"}
#
# ### Merger
#
# >      Merger (game, steps, round_num=1, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Operating

# %%
#| echo: false
#| output: asis
show_doc(Operating)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L6026){target="_blank" style="float:right; font-size:smaller"}
#
# ### Operating
#
# >      Operating (game, steps, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Stock

# %%
#| echo: false
#| output: asis
show_doc(Stock)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L6141){target="_blank" style="float:right; font-size:smaller"}
#
# ### Stock
#
# >      Stock (game, steps, round_num=1, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.
