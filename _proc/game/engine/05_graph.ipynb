# %% [raw]
# ---
# output-file: graph.html
# title: Graph Parts
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Imports

# %%
#| echo: false
#| output: asis
show_doc(copy_dict)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/graph.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### copy_dict
#
# >      copy_dict (dict)

# %% [markdown]
# # Base Classes

# %% [markdown]
# ## Base Part

# %%
#| echo: false
#| output: asis
show_doc(BasePart)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### BasePart
#
# >      BasePart (tile=None, index=None, loc=None, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Node

# %%
#| echo: false
#| output: asis
show_doc(Node)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L61){target="_blank" style="float:right; font-size:smaller"}
#
# ### Node
#
# >      Node (lanes=None, paths=None, exits=None, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Path

# %%
#| echo: false
#| output: asis
show_doc(Path)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L149){target="_blank" style="float:right; font-size:smaller"}
#
# ### Path
#
# >      Path (a, b, terminal=None, lanes=None, track='broad', ignore=None,
# >            ignore_gauge_walk=None, ignore_gauge_compare=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Edge

# %%
#| echo: false
#| output: asis
show_doc(Edge)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L461){target="_blank" style="float:right; font-size:smaller"}
#
# ### Edge
#
# >      Edge (num, lanes=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Frame

# %%
#| echo: false
#| output: asis
show_doc(Frame)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L482){target="_blank" style="float:right; font-size:smaller"}
#
# ### Frame
#
# >      Frame (color, color2=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Future Label

# %%
#| echo: false
#| output: asis
show_doc(FutureLabel)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L492){target="_blank" style="float:right; font-size:smaller"}
#
# ### FutureLabel
#
# >      FutureLabel (label=None, color=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Icon

# %%
#| echo: false
#| output: asis
show_doc(Icon)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L503){target="_blank" style="float:right; font-size:smaller"}
#
# ### Icon
#
# >      Icon (image, name=None, sticky=True, blocks_lay=None, preprinted=True,
# >            large=False, owner=None, loc=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Junction

# %%
#| echo: false
#| output: asis
show_doc(Junction)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L531){target="_blank" style="float:right; font-size:smaller"}
#
# ### Junction
#
# >      Junction (lanes=[], **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Label

# %%
#| echo: false
#| output: asis
show_doc(Label)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L554){target="_blank" style="float:right; font-size:smaller"}
#
# ### Label
#
# >      Label (label=None, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Partition

# %%
#| echo: false
#| output: asis
show_doc(Partition)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L569){target="_blank" style="float:right; font-size:smaller"}
#
# ### Partition
#
# >      Partition (a, b, type, restrict)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Stripes

# %%
#| echo: false
#| output: asis
show_doc(Stripes)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L599){target="_blank" style="float:right; font-size:smaller"}
#
# ### Stripes
#
# >      Stripes (color, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Stub

# %%
#| echo: false
#| output: asis
show_doc(Stub)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L608){target="_blank" style="float:right; font-size:smaller"}
#
# ### Stub
#
# >      Stub (edge, track='broad', **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Upgrade

# %%
#| echo: false
#| output: asis
show_doc(Upgrade)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L621){target="_blank" style="float:right; font-size:smaller"}
#
# ### Upgrade
#
# >      Upgrade (cost, terrains=[], size=0, loc=None, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Part Types

# %% [markdown]
# ## Revenue Center

# %%
#| echo: false
#| output: asis
show_doc(RevenueCenter)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L643){target="_blank" style="float:right; font-size:smaller"}
#
# ### RevenueCenter
#
# >      RevenueCenter (revenue, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Border

# %%
#| echo: false
#| output: asis
show_doc(Border)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L705){target="_blank" style="float:right; font-size:smaller"}
#
# ### Border
#
# >      Border (edge, type=None, cost=None, color=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## City

# %%
#| echo: false
#| output: asis
show_doc(City)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L720){target="_blank" style="float:right; font-size:smaller"}
#
# ### City
#
# >      City (revenue, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Town

# %%
#| echo: false
#| output: asis
show_doc(Town)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L889){target="_blank" style="float:right; font-size:smaller"}
#
# ### Town
#
# >      Town (revenue, to_city=None, boom=None, style=None, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Halt

# %%
#| echo: false
#| output: asis
show_doc(Halt)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L913){target="_blank" style="float:right; font-size:smaller"}
#
# ### Halt
#
# >      Halt (symbol, revenue='0', route='optional', **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Offboard

# %%
#| echo: false
#| output: asis
show_doc(Offboard)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L928){target="_blank" style="float:right; font-size:smaller"}
#
# ### Offboard
#
# >      Offboard (revenue, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Pass

# %%
#| echo: false
#| output: asis
show_doc(Pass)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L936){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pass
#
# >      Pass (revenue, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Top Level Objects

# %% [markdown]
# ## Token

# %%
#| echo: false
#| output: asis
show_doc(Token)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L5270){target="_blank" style="float:right; font-size:smaller"}
#
# ### Token
#
# >      Token (corporation, price=0, logo=None, simple_logo=None, type='normal')
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Graph

# %%
#| echo: false
#| output: asis
show_doc(Graph)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L947){target="_blank" style="float:right; font-size:smaller"}
#
# ### Graph
#
# >      Graph (game, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Distance Graph

# %%
#| echo: false
#| output: asis
show_doc(DistanceGraph)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/part.py#L1219){target="_blank" style="float:right; font-size:smaller"}
#
# ### DistanceGraph
#
# >      DistanceGraph (game, separate_node_types=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Route

# %%
#| echo: false
#| output: asis
show_doc(Route)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/round.py#L3784){target="_blank" style="float:right; font-size:smaller"}
#
# ### Route
#
# >      Route (game, phase, train, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Tile Config (Minimize pls)

# %%
#| echo: false
#| output: asis
show_doc(TileConfig)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/graph.py#L2262){target="_blank" style="float:right; font-size:smaller"}
#
# ### TileConfig
#
# >      TileConfig ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Tile

# %%
#| echo: false
#| output: asis
show_doc(Tile)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/graph.py#L2782){target="_blank" style="float:right; font-size:smaller"}
#
# ### Tile
#
# >      Tile (name, code, color, parts, rotation=0, preprinted=False, index=0,
# >            location_name=None, **opts)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Hex

# %%
#| echo: false
#| output: asis
show_doc(Hex)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/engine/graph.py#L3467){target="_blank" style="float:right; font-size:smaller"}
#
# ### Hex
#
# >      Hex (coordinates, layout=None, axes=None, tile=None, location_name=None,
# >           hide_location_name=False, empty=False)
#
# Initialize self.  See help(type(self)) for accurate signature.
