# %% [raw]
# ---
# output-file: engine.html
# title: Game Engine
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# All games are located within the `games` subdirectory.

# %% [markdown]
# ## Engine

# %%
#| echo: false
#| output: asis
show_doc(GameMap)
# Out:
# ---
#
# [source](https://github.com/Revys17/RL_18xx/blob/master/rl18xx/game/gamemap.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### GameMap
#
# >      GameMap ()
#
# Initialize self.  See help(type(self)) for accurate signature.
